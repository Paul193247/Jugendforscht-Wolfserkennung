# %%
# !pip install ultralytics
# !pip install roboflow
# !tpu-info
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 886.3/886.3 kB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# /bin/bash: line 1: tpu-info: command not found

# %%
from ultralytics import YOLO
import os
import PIL
from PIL import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("/content/yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:02<00:00, 23.5MB/s]

# %%
def train(model, data, resume: bool, folder: str, name:str, time=2, patience=15, epoches=60, batch=-1, device="cuda"):
  model.train(data=data, epochs=60, batch=batch, resume=resume, patience=patience, time=time, project=folder, name=name, device=device, workers=2, cache=False)

# %%
train(model, "/content/drive/MyDrive/jugendForscht/dataset/data.yaml", False, "/content/drive/MyDrive/jugendForscht/model", "v6", time=2.5, batch=8)
# Out:
# Ultralytics 8.3.31 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
